# %%
import numpy as np
from sympy import *
from math import floor
import time

# %%
#Useful functions for both Hypercubes and general Hamming graphs
def read_sets(filename):
    #Read in the sets of a file
    results = []
    with open(filename,'r') as f:
        for line in f.read().splitlines():
            results.append(line.split(','))
    return(results)

def make_linearEqns(A,z):
    #Takes matrix A and variable list z and converts it into a list of linear equations
    z = Matrix(z)
    A = Matrix(A)
    A = A.rref()[0]
    lin_fcns = A*z
    lin_fcns = [f for f in lin_fcns if f != 0]
    return(list(lin_fcns))

# %%
def create_polys(k,a):
    #Setup polynomial system for H_k,a without knowing what R is
    variable_string = 'z1'
    for i in range(1,k*a):
        variable_string = variable_string +',z{} '.format(i+1)
    z = var(variable_string)
    P = []
    f = 0
    for i in range(k):
        func = 0
        #func2 = 0
        for j in range(0,a):
            P.append(z[i*a+j]*(z[i*a+j]-1)*(z[i*a+j]+1)) #1st condition zi*(zi-1)*(zi+1)
            func= func + z[i*a+j]**2
            #func2 = func2 + z[i*a+j]
            f = f + z[i*a+j]**2 #f so that sum(zi**2) neq 0
        func = (2-func)*(func)
        P.append(func)
        #P.append(func2)
    
    fs = [f-2*i for i in range(1,k+1)]
    return(P,fs,z)

def make_matrix(R,k,a):
    #Converts list of one-hot encodings to the linear system
    temp = [r.flatten('F') for r in R]
    for i in range(k):
        added_row = np.zeros(k*a)
        for j in range(a):
            #This is the 2nd condition where sum(zi)_i*a+1^i*a+a = 0
            added_row[i*a+j] = 1
        temp.append(list(added_row))
    return(np.array(temp,dtype = int))

def check_resolving(R,k,a,alphabet = None):
    (P,fs,z) = create_polys(k,a)
    OH_encodedR = OneHot(R,k,a)
    A = make_matrix(OH_encodedR,k,a)
    lin_fcns = make_linearEqns(A,z)
    G = groebner(P+lin_fcns,order = 'lex')
    for fi in fs:
        Gi = groebner(list(G)+[fi],order = 'lex')
        if not (list(Gi) == [1]):
            return False
    return True

# %%
def OneHot(R,k,a,alphabet = None):
    #Converts list of strings to list of one-hot encodings
    if alphabet == None:
        temp = [str(i) for i in range(a)]
        alphabet = ''.join(temp)
    encodings = []
    for r in R:
        encoding = np.zeros((a,k))
        for i in range(k):
            for j,letter in enumerate(alphabet):
                if r[i] == letter:
                    encoding[j,i] = 1
        encodings.append(encoding)
    return(encodings)

def create_polys_improved(k,a):
    #Setup polynomial system for H_k,a without knowing what R is
    variable_string = 'z1'
    for i in range(1,k*a):
        variable_string = variable_string +',z{} '.format(i+1)
    z = var(variable_string)
    P = []
    for i in range(k):
        Pi = []
        func = 0
        #func2 = 0
        for j in range(0,a):
            Pi.append(z[i*a+j]*(z[i*a+j]-1)*(z[i*a+j]+1)) #1st condition zi*(zi-1)*(zi+1)
            func= func + z[i*a+j]**2
            #func2 = func2 + z[i*a+j]
        func = (2-func)*(func)
        Pi.append(func)
        #Pi.append(func2)
        P.append(Pi)
    squares = [zi**2 for zi in z]
    sum_squares = sum(squares)
    f = 1
    for i in range(1,k+1):
        f = f*(2*i - sum_squares)
    return(P,f,z)

def preprocess_groebner(P,z,k,a):
    G0 = groebner(P[0],order = 'lex')
    G = [g for g in list(G0)]
    for i in range(1,k):
        replacements = [(z[j],z[a*i+j]) for j in range(a)]
        for g in list(G0):
            G.append(g.subs(replacements))
    return(G)

def make_matrix_improved(R,k,a):
    #Converts list of one-hot encodings to the linear system
    temp = [r.flatten('F') for r in R]
    for i in range(k):
        added_row = np.zeros(k*a)
        for j in range(a):
            #This is the 2nd condition where sum(zi)_i*a+1^i*a+a = 0
            added_row[i*a+j] = 1
        temp.append(list(added_row))
    return(np.array(temp,dtype = int))

def check_resolving_improved(R,k,a,alphabet = None):
    (P,f,z) = create_polys_improved(k,a)
    OH_encodedR = OneHot(R,k,a)
    A = make_matrix(OH_encodedR,k,a)
    lin_fcns = make_linearEqns(A,z)
    pre_G = preprocess_groebner(P,z,k,a)
    print('Finished Precomputing')
    G = groebner(pre_G+lin_fcns+[f],order = 'lex')
    print('Finished Groebner')
    if list(G) != [1]:
        return False
    return True

# %%
#Using NON-IMPROVED ALGORITHM
sets = read_sets('Test_Sets/H_3_5.txt')
is_resolving = []
time_total = 0
num_sets = 0
for i,R in enumerate(sets):
    start = time.time()
    resolve = check_resolving(R,5,3)
    is_resolving.append(resolve)
    end = time.time()
    time_total = time_total + end-start
    num_sets = num_sets+1
avg_time = time_total/num_sets
for i,r in enumerate(is_resolving):
    if r:
        print('Set {} is resolving'.format(i+1))
    else:
        print('Set {} is not resolving'.format(i+1))
print('Total Time: {:.2f} seconds'.format(time_total))
print('Average time: {:.2f} seconds'.format(avg_time))
# Out:
# Set 1 is resolving
# Set 2 is resolving
# Set 3 is resolving
# Set 4 is not resolving
# Set 5 is not resolving
# Set 6 is not resolving
# Set 7 is resolving
# Set 8 is not resolving
# Total Time: 1.30 seconds
# Average time: 0.16 seconds

# %%
#Using IMPROVED ALGORITHM
sets = read_sets('Test_Sets/H_3_5.txt')
is_resolving = []
time_total = 0
num_sets = 0
for i,R in enumerate(sets):
    start = time.time()
    resolve = check_resolving_improved(R,5,3)
    is_resolving.append(resolve)
    end = time.time()
    time_total = time_total + end-start
    num_sets = num_sets+1
avg_time = time_total/num_sets
for i,r in enumerate(is_resolving):
    if r:
        print('Set {} is resolving'.format(i+1))
    else:
        print('Set {} is not resolving'.format(i+1))
print('Total Time: {:.2f} seconds'.format(time_total))
print('Average time: {:.2f} seconds'.format(avg_time))
# Out:
# Finished Precomputing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6e70cd23228d> in <module>
#       6 for i,R in enumerate(sets):
#       7     start = time.time()
# ----> 8     resolve = check_resolving_improved(R,5,3)
#       9     is_resolving.append(resolve)
#      10     end = time.time()
#
# <ipython-input-4-1119f69dfea1> in check_resolving_improved(R, k, a, alphabet)
#      67     pre_G = preprocess_groebner(P,z,k,a)
#      68     print('Finished Precomputing')
# ---> 69     G = groebner(pre_G+lin_fcns+[f],order = 'lex')
#      70     print('Finished Groebner')
#      71     if list(G) != [1]:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polytools.py in groebner(F, *gens, **args)
#    6745
#    6746     """
# -> 6747     return GroebnerBasis(F, *gens, **args)
#    6748
#    6749
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polytools.py in __new__(cls, F, *gens, **args)
#    6775
#    6776         try:
# -> 6777             polys, opt = parallel_poly_from_expr(F, *gens, **args)
#    6778         except PolificationFailed as exc:
#    6779             raise ComputationFailed('groebner', len(F), exc)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polytools.py in parallel_poly_from_expr(exprs, *gens, **args)
#    4311     """Construct polynomials from expressions. """
#    4312     opt = options.build_options(gens, args)
# -> 4313     return _parallel_poly_from_expr(exprs, opt)
#    4314
#    4315
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polytools.py in _parallel_poly_from_expr(exprs, opt)
#    4350
#    4351                 if opt.expand:
# -> 4352                     expr = expr.expand()
#    4353         else:
#    4354             failed = True
#
# ~\Anaconda3\lib\site-packages\sympy\core\expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3122             if use_hint:
#    3123                 hint = '_eval_expand_' + hint
# -> 3124                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3125
#    3126         while True:
#
# ~\Anaconda3\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3063
#    3064         if hasattr(expr, hint):
# -> 3065             newexpr = getattr(expr, hint)(**hints)
#    3066             if newexpr != expr:
#    3067                 return (newexpr, True)
#
# ~\Anaconda3\lib\site-packages\sympy\core\mul.py in _eval_expand_mul(self, **hints)
#     883             if sums:
#     884                 deep = hints.get("deep", False)
# --> 885                 terms = self.func._expandsums(sums)
#     886                 args = []
#     887                 for term in terms:
#
# ~\Anaconda3\lib\site-packages\sympy\core\mul.py in _expandsums(sums)
#     849
#     850         terms = [Mul(a, b) for a in left for b in right]
# --> 851         added = Add(*terms)
#     852         return Add.make_args(added)  # it may have collapsed down to one term
#     853
#
# ~\Anaconda3\lib\site-packages\sympy\core\operations.py in __new__(cls, *args, **options)
#      43             return args[0]
#      44
# ---> 45         c_part, nc_part, order_symbols = cls.flatten(args)
#      46         is_commutative = not nc_part
#      47         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# ~\Anaconda3\lib\site-packages\sympy\core\add.py in flatten(cls, seq)
#     167             # Mul([...])
#     168             elif o.is_Mul:
# --> 169                 c, s = o.as_coeff_Mul()
#     170
#     171             # check for unevaluated Pow, e.g. 2**3 or 2**(-1/2)
#
# ~\Anaconda3\lib\site-packages\sympy\core\mul.py in as_coeff_Mul(self, rational)
#     775                     return coeff, args[0]
#     776                 else:
# --> 777                     return coeff, self._new_rawargs(*args)
#     778             elif coeff.is_negative:
#     779                 return S.NegativeOne, self._new_rawargs(*((-coeff,) + args))
#
# ~\Anaconda3\lib\site-packages\sympy\core\operations.py in _new_rawargs(self, *args, **kwargs)
#     112         else:
#     113             is_commutative = self.is_commutative
# --> 114         return self._from_args(args, is_commutative)
#     115
#     116     @classmethod
#
# ~\Anaconda3\lib\site-packages\sympy\core\operations.py in _from_args(cls, args, is_commutative)
#      60             return args[0]
#      61
# ---> 62         obj = super(AssocOp, cls).__new__(cls, *args)
#      63         if is_commutative is None:
#      64             is_commutative = fuzzy_and(a.is_commutative for a in args)
#
# KeyboardInterrupt:

# %%
#Using NON-IMPROVED ALGORITHM
sets = read_sets('Test_Sets/H_4_4.txt')
is_resolving = []
time_total = 0
num_sets = 0
for i,R in enumerate(sets):
    start = time.time()
    resolve = check_resolving(R,4,4)
    is_resolving.append(resolve)
    end = time.time()
    time_total = time_total + end-start
    num_sets = num_sets+1
avg_time = time_total/num_sets
for i,r in enumerate(is_resolving):
    if r:
        print('Set {} is resolving'.format(i+1))
    else:
        print('Set {} is not resolving'.format(i+1))
print('Total Time: {:.2f} seconds'.format(time_total))
print('Average time: {:.2f} seconds'.format(avg_time))
# Out:
# Set 1 is resolving
# Set 2 is not resolving
# Set 3 is not resolving
# Set 4 is not resolving
# Set 5 is resolving
# Set 6 is resolving
# Set 7 is resolving
# Set 8 is not resolving
# Total Time: 2.25 seconds
# Average time: 0.28 seconds

# %%
#Using IMPROVED ALGORITHM
sets = read_sets('Test_Sets/H_4_4.txt')
is_resolving = []
time_total = 0
num_sets = 0
for i,R in enumerate(sets):
    start = time.time()
    resolve = check_resolving_improved(R,4,4)
    is_resolving.append(resolve)
    end = time.time()
    time_total = time_total + end-start
    num_sets = num_sets+1
avg_time = time_total/num_sets
for i,r in enumerate(is_resolving):
    if r:
        print('Set {} is resolving'.format(i+1))
    else:
        print('Set {} is not resolving'.format(i+1))
print('Total Time: {:.2f} seconds'.format(time_total))
print('Average time: {:.2f} seconds'.format(avg_time))
# Out:
# Set 1 is resolving
# Set 2 is not resolving
# Set 3 is not resolving
# Set 4 is not resolving
# Set 5 is resolving
# Set 6 is resolving
# Set 7 is resolving
# Set 8 is not resolving
# Total Time: 3.78 seconds
# Average time: 0.47 seconds

# %%
#Using NON-IMPROVED ALGORITHM
sets = read_sets('Test_Sets/H_4_5.txt')
is_resolving = []
time_total = 0
num_sets = 0
for i,R in enumerate(sets):
    start = time.time()
    resolve = check_resolving(R,5,4)
    is_resolving.append(resolve)
    end = time.time()
    time_total = time_total + end-start
    num_sets = num_sets+1
avg_time = time_total/num_sets
for i,r in enumerate(is_resolving):
    if r:
        print('Set {} is resolving'.format(i+1))
    else:
        print('Set {} is not resolving'.format(i+1))
print('Total Time: {:.2f} seconds'.format(time_total))
print('Average time: {:.2f} seconds'.format(avg_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-94cfe58565e4> in <module>()
#       6 for i,R in enumerate(sets):
#       7     start = time.time()
# ----> 8     resolve = check_resolving(R,5,4)
#       9     is_resolving.append(resolve)
#      10     end = time.time()
#
# <ipython-input-40-37f80a901250> in check_resolving(R, k, a, alphabet)
#      27     A = make_matrix(OH_encodedR,k,a)
#      28     lin_fcns = make_linearEqns(A,z)
# ---> 29     G = groebner(P+lin_fcns,order = 'lex')
#      30     for fi in fs:
#      31         Gi = groebner(list(G)+[fi],order = 'lex')
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polytools.py in groebner(F, *gens, **args)
#    6584
#    6585     """
# -> 6586     return GroebnerBasis(F, *gens, **args)
#    6587
#    6588
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polytools.py in __new__(cls, F, *gens, **args)
#    6623         polys = [ring.from_dict(poly.rep.to_dict()) for poly in polys if poly]
#    6624
# -> 6625         G = _groebner(polys, ring, method=opt.method)
#    6626         G = [Poly._from_dict(g, opt) for g in G]
#    6627
#
# ~\Anaconda3\lib\site-packages\sympy\polys\groebnertools.py in groebner(seq, ring, method)
#      43             seq = [ s.set_ring(ring) for s in seq ]
#      44
# ---> 45     G = _groebner(seq, ring)
#      46
#      47     if orig is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\groebnertools.py in _buchberger(f, ring)
#     248
#     249     for ig in G:
# --> 250         ht = normal(f[ig], G - set([ig]))
#     251
#     252         if ht:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\groebnertools.py in normal(g, J)
#     102
#     103     def normal(g, J):
# --> 104         h = g.rem([ f[j] for j in J ])
#     105
#     106         if not h:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\rings.py in rem(self, G)
#    1485                     m, c = tq
#    1486                     for mg, cg in g.iterterms():
# -> 1487                         m1 = monomial_mul(mg, m)
#    1488                         c1 = get(m1, zero) - c*cg
#    1489                         if not c1:
#
# <string> in monomial_mul(A, B)
#
# KeyboardInterrupt:

# %%
#Using IMPROVED ALGORITHM
sets = read_sets('Test_Sets/H_4_5.txt')
is_resolving = []
time_total = 0
num_sets = 0
for i,R in enumerate(sets):
    start = time.time()
    resolve = check_resolving_improved(R,5,4)
    is_resolving.append(resolve)
    end = time.time()
    time_total = time_total + end-start
    num_sets = num_sets+1
avg_time = time_total/num_sets
for i,r in enumerate(is_resolving):
    if r:
        print('Set {} is resolving'.format(i+1))
    else:
        print('Set {} is not resolving'.format(i+1))
print('Total Time: {:.2f} seconds'.format(time_total))
print('Average time: {:.2f} seconds'.format(avg_time))
